# %% [markdown]
# #  libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set()

# %% [markdown]
# #  IMPORTING DATA

# %%
data = pd.read_csv(r"C:\Users\aryan\Desktop\datasets\Countries-exercise.csv")
data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %%
data.head(10)
# Out:
#                    name  Longitude   Latitude
# 0                 Aruba -69.982677  12.520880
# 1           Afghanistan  66.004734  33.835231
# 2                Angola  17.537368 -12.293361
# 3              Anguilla -63.064989  18.223959
# 4               Albania  20.049834  41.142450
# 5                 Aland  19.953288  60.214887
# 6               Andorra   1.560544  42.542291
# 7  United Arab Emirates  54.300167  23.905282
# 8             Argentina -65.179807 -35.381349
# 9               Armenia  44.929933  40.289526

# %% [markdown]
# #  DATA PLOT
# 1

# %%
plot = plt.scatter(data['Longitude'],data['Latitude'])
plt.xlabel('longitudes')
plt.ylabel('latitudes')
plt.show()

# %%
# BY LOOKING AT THE PLOT WE CAN ASSUME THAT THE DATA CAN BE 
# CLUSTERED INTO 4 GROUPS.

# %% [markdown]
# # FEATURE SEPARATION

# %%
x_features = data.iloc[:,1:3]
x_features
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %% [markdown]
# #  IMPORTING KMEANS

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(4)

# %%
found_cluster = kmeans.fit_predict(x_features)

# %%
data_with_cluster = data.copy()
data_with_cluster['cluster'] = found_cluster
data_with_cluster
# Out:
#              name   Longitude   Latitude  cluster
# 0           Aruba  -69.982677  12.520880        1
# 1     Afghanistan   66.004734  33.835231        3
# 2          Angola   17.537368 -12.293361        3
# 3        Anguilla  -63.064989  18.223959        1
# 4         Albania   20.049834  41.142450        0
# ..            ...         ...        ...      ...
# 236         Samoa -172.164851 -13.753243        1
# 237         Yemen   47.586762  15.909280        3
# 238  South Africa   25.083901 -29.000341        3
# 239        Zambia   27.774759 -13.458242        3
# 240      Zimbabwe   29.851441 -19.004204        3
#
# [241 rows x 4 columns]

# %%
data_with_cluster.tail(10)
# Out:
#                       name   Longitude   Latitude  cluster
# 231     British Virgin Is.  -64.471470  18.525858        1
# 232        U.S. Virgin Is.  -64.803015  17.955006        1
# 233                Vietnam  106.299147  16.646017        2
# 234                Vanuatu  167.686446 -16.226409        2
# 235  Wallis and Futuna Is. -177.348348 -13.887370        1
# 236                  Samoa -172.164851 -13.753243        1
# 237                  Yemen   47.586762  15.909280        3
# 238           South Africa   25.083901 -29.000341        3
# 239                 Zambia   27.774759 -13.458242        3
# 240               Zimbabwe   29.851441 -19.004204        3

# %% [markdown]
# #  PLOTTING CLUSTER

# %%
plt.scatter(data_with_cluster["Longitude"],data_with_cluster['Latitude'], c = data_with_cluster['cluster'],cmap='rainbow')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
