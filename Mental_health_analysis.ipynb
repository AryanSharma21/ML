# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Loading the required data

# %%
data = pd.read_csv(r'C:\Users\aryan\Desktop\datasets\Student Mental health.csv')
data.head(1)
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
#
#   Did you seek any specialist for a treatment?
# 0                                           No

# %%
data.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
data.shape
# Out:
# (101, 11)

# %%
data.dropna()
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
plt.plot(data['Age'], data['Do you have Depression?'])

# %%
plt.scatter(data['Age'], data['Do you have Depression?'])

# %%
data.columns
# Out:
# Index(['Timestamp', 'Choose your gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
data.columns = ['Timestamp', 'Gender', 'Age', 'course','YOS','CGPA','Marital_status','Depression','Anxiety' ,'Panic','treatment']

# %%
data
# Out:
#                Timestamp  Gender   Age              course     YOS  \
# 0         8/7/2020 12:02  Female  18.0         Engineering  year 1
# 1         8/7/2020 12:04    Male  21.0   Islamic education  year 2
# 2         8/7/2020 12:05    Male  19.0                 BIT  Year 1
# 3         8/7/2020 12:06  Female  22.0                Laws  year 3
# 4         8/7/2020 12:13    Male  23.0        Mathemathics  year 4
# ..                   ...     ...   ...                 ...     ...
# 96   13/07/2020 19:56:49  Female  21.0                 BCS  year 1
# 97   13/07/2020 21:21:42    Male  18.0         Engineering  Year 2
# 98   13/07/2020 21:22:56  Female  19.0            Nursing   Year 3
# 99   13/07/2020 21:23:57  Female  23.0    Pendidikan Islam  year 4
# 100  18/07/2020 20:16:21    Male  20.0  Biomedical science  Year 2
#
#             CGPA Marital_status Depression Anxiety Panic treatment
# 0    3.00 - 3.49             No        Yes      No   Yes        No
# ...

# %%
data.Gender
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3      Female
# 4        Male
#         ...
# 96     Female
# 97       Male
# 98     Female
# 99     Female
# 100      Male
# Name: Gender, Length: 101, dtype: object

# %%
male_data = data[data.Gender=='Male']

# %%
male_data
# Out:
#                Timestamp Gender   Age              course     YOS  \
# 1         8/7/2020 12:04   Male  21.0   Islamic education  year 2
# 2         8/7/2020 12:05   Male  19.0                 BIT  Year 1
# 4         8/7/2020 12:13   Male  23.0        Mathemathics  year 4
# 5         8/7/2020 12:31   Male  19.0         Engineering  Year 2
# 9         8/7/2020 12:39   Male  18.0               Irkhs  year 1
# 13        8/7/2020 12:41   Male  19.0         Engineering  year 1
# 15        8/7/2020 12:43   Male  24.0                 BCS  Year 3
# 27        8/7/2020 13:41   Male  18.0         Engineering  Year 2
# 31        8/7/2020 14:29   Male  18.0                 BCS  year 2
# 32        8/7/2020 14:29   Male  19.0                 BCS  year 1
# 33        8/7/2020 14:31   Male  18.0                 BCS  Year 2
# 43        8/7/2020 15:07   Male   NaN                 BIT  year 1
# 44        8/7/2020 15:08   Male  23.0               TAASL  year 2
# ...

# %%
plt.bar(male_data['Age'], male_data['Depression'])
# Out:
# <BarContainer object of 26 artists>

# %%
male_data.describe()
# Out:
#             Age
# count  25.00000
# mean   20.52000
# std     2.48529
# min    18.00000
# 25%    18.00000
# 50%    19.00000
# 75%    23.00000
# max    24.00000

# %%
male_data.Depression.replace(('Yes','No'),(1,0), inplace=True)
male_data.Anxiety.replace(('Yes','No'),(1,0), inplace=True)
male_data.Panic.replace(('Yes','No'),(1,0), inplace=True)
male_data.treatment.replace(('Yes','No'),(1,0), inplace=True)
male_data.Marital_status.replace(('Yes','No'),(1,0), inplace=True)
# Out:
# C:\Users\aryan\AppData\Local\Temp\ipykernel_4248\4268227964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_data.Depression.replace(('Yes','No'),(1,0), inplace=True)
# C:\Users\aryan\AppData\Local\Temp\ipykernel_4248\4268227964.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_data.Anxiety.replace(('Yes','No'),(1,0), inplace=True)
# C:\Users\aryan\AppData\Local\Temp\ipykernel_4248\4268227964.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
male_data
# Out:
#                Timestamp Gender   Age              course     YOS  \
# 1         8/7/2020 12:04   Male  21.0   Islamic education  year 2
# 2         8/7/2020 12:05   Male  19.0                 BIT  Year 1
# 4         8/7/2020 12:13   Male  23.0        Mathemathics  year 4
# 5         8/7/2020 12:31   Male  19.0         Engineering  Year 2
# 9         8/7/2020 12:39   Male  18.0               Irkhs  year 1
# 13        8/7/2020 12:41   Male  19.0         Engineering  year 1
# 15        8/7/2020 12:43   Male  24.0                 BCS  Year 3
# 27        8/7/2020 13:41   Male  18.0         Engineering  Year 2
# 31        8/7/2020 14:29   Male  18.0                 BCS  year 2
# 32        8/7/2020 14:29   Male  19.0                 BCS  year 1
# 33        8/7/2020 14:31   Male  18.0                 BCS  Year 2
# 43        8/7/2020 15:07   Male   NaN                 BIT  year 1
# 44        8/7/2020 15:08   Male  23.0               TAASL  year 2
# ...

# %%
#Now we will visualize the plots

# %%
plt.scatter(male_data['Marital_status'],male_data['Depression'])
plt.xlabel('Marital status')
plt.ylabel('Depression')
plt.show()

# %%
plt.plot(male_data['Marital_status'],male_data['Depression'])

# %%
sns.boxenplot(x='Depression',y='Marital_status',data=male_data)
# Out:
# <AxesSubplot:xlabel='Depression', ylabel='Marital_status'>

# %%
sns.boxenplot(x='Depression',y='CGPA',data=male_data)
# Out:
# <AxesSubplot:xlabel='Depression', ylabel='CGPA'>

# %%
sns.boxenplot(x='Depression',y='Age',data=male_data)
# Out:
# <AxesSubplot:xlabel='Depression', ylabel='Age'>

# %%
#Dropping irrelevent columns

# %%
male_data.drop(['Timestamp','Gender','course','YOS'],axis=1)
# Out:
#       Age         CGPA  Marital_status  Depression  Anxiety  Panic  treatment
# 1    21.0  3.00 - 3.49               0           0        1      0          0
# 2    19.0  3.00 - 3.49               0           1        1      1          0
# 4    23.0  3.00 - 3.49               0           0        0      0          0
# 5    19.0  3.50 - 4.00               0           0        0      1          0
# 9    18.0  3.50 - 4.00               0           0        1      1          0
# 13   19.0  3.00 - 3.49               0           0        0      0          0
# 15   24.0  3.50 - 4.00               0           0        0      0          0
# 27   18.0  3.00 - 3.49               1           1        1      0          0
# 31   18.0  3.00 - 3.49               0           0        0      0          0
# 32   19.0  3.50 - 4.00               0           0        0      1          0
# 33   18.0  3.50 - 4.00               1           1        1      0          1
# ...

# %%
male_data = male_data.reset_index()

# %%
#feature and target split

# %%
feature = ['Age','Marital_status','Anxiety','Panic','treatment']
x_feature = male_data.loc[:,feature]
x_feature.head(1)
# Out:
#     Age  Marital_status  Anxiety  Panic  treatment
# 0  21.0               0        1      0          0

# %%
y_target = male_data.loc[:,['Depression']]
y_target.head(5)
# Out:
#    Depression
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0

# %%
#train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_feature,y_target,random_state=0,train_size=0.80)
y_test.shape
# Out:
# (6, 1)

# %%
#Now applying logistic regression algorithm

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# F:\conda\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()
