# %% [markdown]
# Outlines :
# 1. Importing libraries
# 2. Missing values imputation(data preprocessing)
# 3. EDA
# 4. Feature Engineering
# 5. Model Building
# 6. Model evaluation

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings 
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)

# %% [markdown]
# Importing Data sets

# %%
general_data = pd.read_csv(r'C:\Users\aryan\Desktop\DataSets-master\general_data.csv')

# %%
manager_survey_data = pd.read_csv(r'C:\Users\aryan\Desktop\DataSets-master\manager_survey_data.csv')

# %%
employee_survey_data = pd.read_csv(r'C:\Users\aryan\Desktop\DataSets-master\employee_survey_data.csv')

# %%
in_time = pd.read_csv(r'C:\Users\aryan\Desktop\DataSets-master\in_time.csv')
out_time = pd.read_csv(r'C:\Users\aryan\Desktop\DataSets-master\out_time.csv')

# %%
data_dictionary = pd.read_excel(r'C:\Users\aryan\Desktop\DataSets-master\data_dictionary.xlsx')

# %%
general_data
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %% [markdown]
# Pre-Processing Start :

# %%
manager_survey_data.head(5)
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating
# 0           1               3                  3
# 1           2               2                  4
# 2           3               3                  3
# 3           4               2                  3
# 4           5               3                  3

# %%
employee_survey_data.head(5)
# Out:
#    EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0           1                      3.0              4.0              2.0
# 1           2                      3.0              2.0              4.0
# 2           3                      2.0              2.0              1.0
# 3           4                      4.0              4.0              3.0
# 4           5                      4.0              1.0              3.0

# %%
in_time.head(5)
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06         NaN
# ...

# %%
out_time.head(5)
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                  NaN  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 17:38:29  2015-01-12 16:58:39  2015-01-13 18:02:58         NaN
# ...

# %%
data_dictionary.head(5)
# Out:
#            Variable                                            Meaning Levels
# 0               Age                                Age of the employee    NaN
# 1         Attrition  Whether the employee left in the previous year...    NaN
# 2    BusinessTravel  How frequently the employees travelled for bus...    NaN
# 3        Department                              Department in company    NaN
# 4  DistanceFromHome                          Distance from home in kms    NaN

# %% [markdown]
# # Working with In time and out time data

# %%
in_time.drop(['Unnamed: 0'],inplace=True,axis=1)

# %%
out_time.drop(['Unnamed: 0'],inplace=True,axis=1)

# %%
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Columns: 249 entries, 2015-01-02 to 2015-12-31
# dtypes: timedelta64[ns](249)
# memory usage: 8.4 MB

# %%
import datetime as dt

# %% [markdown]
# # Converting the duration from TimeDelta to total hours

# %%
def fetch(col):
    return float(col.total_seconds()//3600)

# %%
duration=duration.applymap(fetch)

# %% [markdown]
# # Calculating Average duration of whole year:

# %%
average_duration = duration.mean(axis=1)

# %%
average_duration=pd.DataFrame(average_duration,columns=['Average_time'])

# %%
average_duration
# Out:
#       Average_time
# 0         6.905172
# 1         7.165254
# 2         6.483471
# 3         6.740426
# 4         7.469388
# ...            ...
# 4405      8.049383
# 4406      5.668050
# 4407      7.160173
# 4408      8.991701
# 4409      6.478448
#
# [4410 rows x 1 columns]

# %% [markdown]
# # Append EmployeeID so we can join

# %%
average_duration['EmployeeID'] = np.arange(1,4411)

# %%
average_duration = average_duration.iloc[:,[1,0]]

# %%
average_duration
# Out:
#       EmployeeID  Average_time
# 0              1      6.905172
# 1              2      7.165254
# 2              3      6.483471
# 3              4      6.740426
# 4              5      7.469388
# ...          ...           ...
# 4405        4406      8.049383
# 4406        4407      5.668050
# 4407        4408      7.160173
# 4408        4409      8.991701
# 4409        4410      6.478448
#
# [4410 rows x 2 columns]

# %% [markdown]
# #  Merging

# %%
data = pd.merge(general_data,manager_survey_data,on='EmployeeID',how='inner')
data = pd.merge(data,employee_survey_data,on='EmployeeID',how='inner')
data = pd.merge(data,average_duration,on='EmployeeID',how='inner')

# %%
data
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
data.nunique()
# Out:
# Age                          43
# Attrition                     2
# BusinessTravel                3
# Department                    3
# DistanceFromHome             29
# Education                     5
# EducationField                6
# EmployeeCount                 1
# EmployeeID                 4410
# Gender                        2
# JobLevel                      5
# JobRole                       9
# MaritalStatus                 3
# MonthlyIncome              1349
# NumCompaniesWorked           10
# Over18                        1
# PercentSalaryHike            15
# StandardHours                 1
# StockOptionLevel              4
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# YearsAtCompany               37
# YearsSinceLastPromotion      16
# YearsWithCurrManager         18
# JobInvolvement                4
# PerformanceRating             2
# EnvironmentSatisfaction       4
# JobSatisfaction               4
# WorkLifeBalance               4
# ...

# %%
data.drop(columns=['EmployeeCount','Over18','StandardHours'],inplace=True,axis=1)

# %%
data
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeID  Gender  \
# 0                    6          2  Life Sciences           1  Female
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# PercentSalaryHike           0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# JobInvolvement              0
# PerformanceRating           0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# Average_time                0
# dtype: int64

# %% [markdown]
# # To fill the null values we need to make some plots to understand -
#
#
# # if we should fill with mean of column or mode

# %%
def make_plot(feature):
    plt.figure(figsize=(18,7))
    sns.countplot(x=feature, hue ='Attrition',data=data)
    plt.xlabel(feature,fontsize=14)
    plt.ylabel('EmployeeCount',fontsize=14)
    plt.title('{} vs Attrition'.format(feature),fontsize=20)

# %%
make_plot('NumCompaniesWorked')

# %%
make_plot('EnvironmentSatisfaction')

# %%
make_plot('JobSatisfaction')

# %%
make_plot('WorkLifeBalance')

# %%
data['WorkLifeBalance'].fillna(3.0,inplace=True)
data['JobSatisfaction'].fillna(4.0,inplace=True)
data['EnvironmentSatisfaction'].fillna(3.0,inplace=True)
data['TotalWorkingYears'].fillna(10.0,inplace=True)
data['NumCompaniesWorked'].fillna(1.0,inplace=True)

# %% [raw]
# ############ you have to make a function that will take all columns of your df and then first will
# filter object dtype column and in those check if unique values are more than and equal to 7 then fill missing data with median
#  and if less than 7 then fill missing data with mode

# %%
def autofilter(df):
    ls = list(df.select_dtypes('object'))
    print(ls)
    for i in ls:
        if df[i].nunique() >=7:
            df[i].fillna(df[i].median,inplace = True)
        else:
            df[i].fillna(df[i].mode()[0],inplace=True)

# %%
autofilter(data)
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus']

# %% [markdown]
# # Encoding the data of required columns

# %%
one_hot_var = ['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus']

for i in one_hot_var:
    x_t = pd.get_dummies(data[i],prefix = i,prefix_sep='_',drop_first=True)
    data = data.join(x_t)
    data.drop(i,axis=1,inplace=True)

# %%
data
# Out:
#       Age Attrition  DistanceFromHome  Education  EmployeeID  JobLevel  \
# 0      51        No                 6          2           1         1
# 1      31       Yes                10          1           2         1
# 2      32        No                17          4           3         4
# 3      38        No                 2          5           4         3
# 4      32        No                10          1           5         1
# ...   ...       ...               ...        ...         ...       ...
# 4405   42        No                 5          4        4406         1
# 4406   29        No                 2          4        4407         1
# 4407   25        No                25          2        4408         2
# 4408   42        No                18          2        4409         1
# 4409   40        No                28          3        4410         2
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# ...

# %% [markdown]
# #  Encoding target variables without one-hot

# %%
data['Attrition'] = data['Attrition'].map({'No':0,'Yes':1})
data
# Out:
#       Age  Attrition  DistanceFromHome  Education  EmployeeID  JobLevel  \
# 0      51          0                 6          2           1         1
# 1      31          1                10          1           2         1
# 2      32          0                17          4           3         4
# 3      38          0                 2          5           4         3
# 4      32          0                10          1           5         1
# ...   ...        ...               ...        ...         ...       ...
# 4405   42          0                 5          4        4406         1
# 4406   29          0                 2          4        4407         1
# 4407   25          0                25          2        4408         2
# 4408   42          0                18          2        4409         1
# 4409   40          0                28          3        4410         2
#
#       MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# ...

# %% [markdown]
# # SMOTE target variable to avoid bias due to imbalance in target column

# %%
#pip install imblearn

# %%
x = data.drop('Attrition',axis=1)
y = pd.DataFrame(data['Attrition'],columns=['Attrition'])

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(sampling_strategy='minority')
x_sm , y_sm = smote.fit_resample(x,y)

# %%
y_sm.value_counts()
# Out:
# Attrition
# 0            3699
# 1            3699
# dtype: int64

# %% [markdown]
# # Oversampling completed
# # Data is ready to fit to the algorithm

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_sm,y_sm,train_size=0.75,random_state=25)

# %%
## Function to list all the columns which have corelation more than 0.8 so we can remove them and avoid overfitting. in x_train

def corelation_filter(df):
    ls = []
    cor_matrix = df.corr().abs()
    for i in range(len(cor_matrix)):
        for j in range(i) :
            if i == j:
                continue
            else:
                if cor_matrix.iloc[i,j] >0.8:
                    ls.append(cor_matrix.columns[i])
                    ls.append(cor_matrix.columns[j])
                    print(ls)

# %%
corelation_filter(x_train)

# %% [markdown]
# #  Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train[x_train.columns] = scaler.fit_transform(x_train[x_train.columns])
x_test[x_test.columns] = scaler.fit_transform(x_test[x_test.columns])

# %% [markdown]
# # Model Building

# %% [markdown]
# # Decision Tree classifier

# %%
## Model Building 
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

model.fit(x_train,y_train)
y_pred = model.predict(x_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.8248648648648649

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_pred,y_test)
# Out:
# array([[635,  35],
#        [289, 891]], dtype=int64)

# %% [markdown]
# #  Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
log_model.fit(x_train,y_train)

predicted = log_model.predict(x_test)
accuracy_score(predicted,y_test)
# Out:
# 0.8767567567567568

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(predicted,y_test)
# Out:
# array([[852, 156],
#        [ 72, 770]], dtype=int64)

# %% [markdown]
# # END
